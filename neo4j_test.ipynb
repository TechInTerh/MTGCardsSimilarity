# %%
from neo4j import GraphDatabase, RoutingControl

# %%
URI = "bolt://localhost:7687"
AUTH= ("neo4j","12345678")

# %%
driver = GraphDatabase.driver(URI)
driver.verify_authentication()
# Out:
# True

# %%
def add_friend(driver, name, friend_name):
    driver.execute_query(
        "MERGE (a:Person {name: $name}) "
        "MERGE (friend:Person {name: $friend_name}) "
        "MERGE (a)-[:KNOWS]->(friend)",
        name=name, friend_name=friend_name, database_="neo4j",
    )


def print_friends(driver, name):
    records, _, _ = driver.execute_query(
        "MATCH (a:Person)-[:KNOWS]->(friend) WHERE a.name = $name "
        "RETURN friend.name ORDER BY friend.name",
        name=name, database_="neo4j", routing_=RoutingControl.READ,
    )
    for record in records:
        print(record["friend.name"])
add_friend(driver,"Arthur","Gui")
add_friend(driver,"Arthur","Victor")
print_friends(driver,"Arthur")
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[9], line 18
#      16     for record in records:
#      17         print(record["friend.name"])
# ---> 18 add_friend(driver,"Arthur","Gui")
#      19 add_friend(driver,"Arthur","Victor")
#      20 print_friends(driver,"Arthur")
#
# Cell In[9], line 2, in add_friend(driver, name, friend_name)
#       1 def add_friend(driver, name, friend_name):
# ----> 2     driver.execute_query(
#       3         "MERGE (a:Person {name: $name}) "
#       4         "MERGE (friend:Person {name: $friend_name}) "
#       5         "MERGE (a)-[:KNOWS]->(friend)",
#       6         name=name, friend_name=friend_name, database_="neo4j",
#       7     )
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/driver.py:920, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     917     raise ValueError("Invalid routing control value: %r"
#     918                      % routing_)
#     919 with session._pipelined_begin:
# --> 920     return session._run_transaction(
#     921         access_mode, TelemetryAPI.DRIVER,
#     922         work, (query_str, parameters, result_transformer_), {}
#     923     )
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/work/session.py:543, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     541 while True:
#     542     try:
# --> 543         self._open_transaction(
#     544             tx_cls=ManagedTransaction,
#     545             api=None if telemetry_sent else api,
#     546             access_mode=access_mode, metadata=metadata,
#     547             timeout=timeout, api_success_cb=api_success_cb,
#     548         )
#     549         assert isinstance(self._transaction, ManagedTransaction)
#     550         tx = self._transaction
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/work/session.py:434, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     427 self._transaction = tx_cls(
#     428     self._connection, self._config.fetch_size,
#     429     self._transaction_closed_handler,
#     430     self._transaction_error_handler,
#     431     self._transaction_cancel_handler
#     432 )
#     433 bookmarks = self._get_bookmarks()
# --> 434 self._transaction._begin(
#     435     self._config.database, self._config.impersonated_user,
#     436     bookmarks, access_mode, metadata, timeout,
#     437     self._config.notifications_min_severity,
#     438     self._config.notifications_disabled_categories,
#     439     pipelined=self._pipelined_begin
#     440 )
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/work/transaction.py:81, in TransactionBase._begin(self, database, imp_user, bookmarks, access_mode, metadata, timeout, notifications_min_severity, notifications_disabled_categories, pipelined)
#      74 @NonConcurrentMethodChecker.non_concurrent_method
#      75 def _begin(
#      76     self, database, imp_user, bookmarks, access_mode, metadata, timeout,
#      77     notifications_min_severity, notifications_disabled_categories,
#      78     pipelined=False,
#      79 ):
#      80     self._database = database
# ---> 81     self._connection.begin(
#      82         bookmarks=bookmarks, metadata=metadata, timeout=timeout,
#      83         mode=access_mode, db=database, imp_user=imp_user,
#      84         notifications_min_severity=notifications_min_severity,
#      85         notifications_disabled_categories=notifications_disabled_categories
#      86     )
#      87     if not pipelined:
#      88         self._error_handling_connection.send_all()
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_bolt3.py:342, in Bolt3.begin(self, mode, bookmarks, metadata, timeout, db, imp_user, notifications_min_severity, notifications_disabled_categories, dehydration_hooks, hydration_hooks, **handlers)
#     337 def begin(self, mode=None, bookmarks=None, metadata=None, timeout=None,
#     338           db=None, imp_user=None, notifications_min_severity=None,
#     339           notifications_disabled_categories=None, dehydration_hooks=None,
#     340           hydration_hooks=None, **handlers):
#     341     if db is not None:
# --> 342         raise ConfigurationError(
#     343             "Database name parameter for selecting database is not "
#     344             "supported in Bolt Protocol {!r}. Database name {!r}.".format(
#     345                 self.PROTOCOL_VERSION, db
#     346             )
#     347         )
#     348     if imp_user is not None:
#     349         raise ConfigurationError(
#     350             "Impersonation is not supported in Bolt Protocol {!r}. "
#     351             "Trying to impersonate {!r}.".format(
#     352                 self.PROTOCOL_VERSION, imp_user
#     353             )
#     354         )
#
# ConfigurationError: Database name parameter for selecting database is not supported in Bolt Protocol Version(3, 0). Database name 'neo4j'.

# %%
GraphDatabase.
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_bolt3.py:448, in Bolt3._process_message(self, tag, fields)
#     447 try:
# --> 448     response.on_failure(summary_metadata or {})
#     449 except (ServiceUnavailable, DatabaseUnavailable):
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:269, in InitResponse.on_failure(self, metadata)
#     265 metadata["message"] = metadata.get(
#     266     "message",
#     267     "Connection initialisation failed due to an unknown error"
#     268 )
# --> 269 raise Neo4jError.hydrate(**metadata)
#
# AuthError: {code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.}
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 driver.verify_connectivity()
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/driver.py:1025, in Driver.verify_connectivity(self, **config)
#    1018     experimental_warn(
#    1019         "All configuration key-word arguments to "
#    1020         "verify_connectivity() are experimental. They might be "
#    1021         "changed or removed in any future version without prior "
#    1022         "notice."
#    1023     )
#    1024 session_config = self._read_session_config(config)
# -> 1025 self._get_server_info(session_config)
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/driver.py:1236, in Driver._get_server_info(self, session_config)
#    1234 def _get_server_info(self, session_config) -> ServerInfo:
#    1235     with self._session(session_config) as session:
# -> 1236         return session._get_server_info()
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/work/session.py:172, in Session._get_server_info(self)
#     170 def _get_server_info(self):
#     171     assert not self._connection
# --> 172     self._connect(READ_ACCESS, liveness_check_timeout=0)
#     173     server_info = self._connection.server_info
#     174     self._disconnect()
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/work/session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     128     access_mode = self._config.default_access_mode
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#     134     self._handle_cancellation(message="_connect")
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/work/workspace.py:178, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     169 acquire_kwargs_ = {
#     170     "access_mode": access_mode,
#     171     "timeout": acquisition_timeout,
#    (...)
#     175     "liveness_check_timeout": None,
#     176 }
#     177 acquire_kwargs_.update(acquire_kwargs)
# --> 178 self._connection = self._pool.acquire(**acquire_kwargs_)
#     179 self._connection_access_mode = access_mode
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:526, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout)
#     523 log.debug("[#0000]  _: <POOL> acquire direct connection, "
#     524           "access_mode=%r, database=%r", access_mode, database)
#     525 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 526 return self._acquire(
#     527     self.address, auth, deadline, liveness_check_timeout
#     528 )
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:313, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     308             raise ClientError(
#     309                 "failed to obtain a connection from the pool within "
#     310                 "{!r}s (timeout)".format(deadline.original_timeout)
#     311             )
#     312 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 313 return connection_creator()
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:163, in IOPool._acquire_new_later.<locals>.connection_creator()
#     161 try:
#     162     try:
# --> 163         connection = self.opener(
#     164             address, auth or self.pool_config.auth, deadline
#     165         )
#     166     except ServiceUnavailable:
#     167         self.deactivate(address)
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:500, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     499 def opener(addr, auth_manager, deadline):
# --> 500     return Bolt.open(
#     501         addr, auth_manager=auth_manager, deadline=deadline,
#     502         routing_context=None, pool_config=pool_config
#     503     )
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:488, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     486 connection.socket.set_deadline(deadline)
#     487 try:
# --> 488     connection.hello()
#     489 finally:
#     490     connection.socket.set_deadline(None)
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_bolt3.py:217, in Bolt3.hello(self, dehydration_hooks, hydration_hooks)
#     212 self._append(b"\x01", (headers,),
#     213              response=InitResponse(self, "hello", hydration_hooks,
#     214                                    on_success=self.server_info.update),
#     215              dehydration_hooks=dehydration_hooks)
#     216 self.send_all()
# --> 217 self.fetch_all()
#     218 check_supported_server_product(self.server_info.agent)
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:864, in Bolt.fetch_all(self)
#     862 response = self.responses[0]
#     863 while not response.complete:
# --> 864     detail_delta, summary_delta = self.fetch_message()
#     865     detail_count += detail_delta
#     866     summary_count += summary_delta
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:850, in Bolt.fetch_message(self)
#     846 # Receive exactly one message
#     847 tag, fields = self.inbox.pop(
#     848     hydration_hooks=self.responses[0].hydration_hooks
#     849 )
# --> 850 res = self._process_message(tag, fields)
#     851 self.idle_since = monotonic()
#     852 return res
#
# File ~/Documents/MTGCardsSimilarity/venv/lib/python3.10/site-packages/neo4j/_sync/io/_bolt3.py:461, in Bolt3._process_message(self, tag, fields)
#     459         raise
#     460     except Neo4jError as e:
# --> 461         self.pool.on_neo4j_error(e, self)
#     462         raise
#     463 else:
#
# AttributeError: 'NoneType' object has no attribute 'on_neo4j_error'
